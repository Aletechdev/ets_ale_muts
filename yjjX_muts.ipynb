# %%
import pandas as pd
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 200)

# %%
all_muts_df = pd.read_pickle("./data/2_2_df.pkl")
display(len(all_muts_df), all_muts_df.head())
# Out:
# 585
#   index  exp  ale  flask  isolate  tech_rep  presence  Position Mutation Type  \
# 0  1392  GLU    3    412        2         1       1.0     13957           SNP
# 1  1428  GLU    3    412        2         1       1.0     28175           SNP
# 2  1393  GLU    3    412        2         1       1.0    101342           SNP
# 3  1394  GLU    3    412        2         1       1.0    145691           SNP
# 4  1429  GLU    3    412        2         1       1.0    171072           SNP
#
#   Sequence Change          Details mutation target annotation Reference Seq  \
# 0             A→T  M599L (ATG→TTG)                       dnaK     NC_000913
# 1             T→A  W295R (TGG→AGG)                       rihC     NC_000913
# 2             C→T  T193I (ACC→ATC)                       murC     NC_000913
# 3             C→T  A204V (GCC→GTC)                       yadE     NC_000913
# 4             A→G  K166K (AAA→AAG)                       fhuD     NC_000913
#
#       sample  coding             range gene RegulonDB ID  \
# 0  3 412 2 1    True    (13957, 13957)    {ECK120000235}
# 1  3 412 2 1    True    (28175, 28175)    {ECK120001070}
# 2  3 412 2 1    True  (101342, 101342)    {ECK120000612}
# 3  3 412 2 1    True  (145691, 145691)    {ECK120001687}
# 4  3 412 2 1    True  (171072, 171072)    {ECK120000299}
#
#                                     genetic features   oriC  pseudogene TFBS  \
# 0  [{'name': 'dnaK', 'RegulonDB ID': 'ECK12000023...  False       False   {}
# 1  [{'name': 'rihC', 'RegulonDB ID': 'ECK12000107...  False       False   {}
# 2  [{'name': 'murC', 'RegulonDB ID': 'ECK12000061...  False       False   {}
# 3  [{'name': 'yadE', 'RegulonDB ID': 'ECK12000168...  False       False   {}
# 4  [{'name': 'fhuD', 'RegulonDB ID': 'ECK12000029...  False       False   {}
#
#   promoter RBS terminator  genetic  \
# 0       {}  {}         {}     True
# 1       {}  {}         {}     True
# 2       {}  {}         {}     True
# 3       {}  {}         {}     True
# 4       {}  {}         {}     True
#
#                                     genomic features
# 0  [{'name': 'dnaK', 'RegulonDB ID': 'ECK12000023...
# 1  [{'name': 'rihC', 'RegulonDB ID': 'ECK12000107...
# 2  [{'name': 'murC', 'RegulonDB ID': 'ECK12000061...
# 3  [{'name': 'yadE', 'RegulonDB ID': 'ECK12000168...
# 4  [{'name': 'fhuD', 'RegulonDB ID': 'ECK12000029...

# %%
meta_muts = pd.DataFrame()
for _, r in all_muts_df.iterrows():  # Using genomic features ensures I get any large deletions
    for f in r["genomic features"]:
        if f["name"]=="yjjX":
            meta_muts = meta_muts.append(r, ignore_index=True)
            break
display(len(meta_muts), meta_muts.head())
# Out:
# 4
#            Details Mutation Type   Position RBS Reference Seq Sequence Change  \
# 0  M1M (ATG→ATA) †           SNP  4633743.0  {}     NC_000913             C→T
# 1   E38K (GAG→AAG)           SNP  4633634.0  {}     NC_000913             C→T
# 2   C30Y (TGC→TAC)           SNP  4633657.0  {}     NC_000913             C→T
# 3   C30Y (TGC→TAC)           SNP  4633657.0  {}     NC_000913             C→T
#
#   TFBS   ale  coding            exp  flask gene RegulonDB ID  genetic  \
# 0   {}   9.0     1.0  ndh-cydB-appC   30.0    {ECK120002327}      1.0
# 1   {}  10.0     1.0  ndh-cydB-appC   32.0    {ECK120002327}      1.0
# 2   {}  11.0     1.0  ndh-cydB-appC   63.0    {ECK120002327}      1.0
# 3   {}  12.0     1.0  ndh-cydB-appC   60.0    {ECK120002327}      1.0
#
#                                     genetic features  \
# 0  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...
# 1  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...
# 2  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...
# 3  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...
#
#                                     genomic features index  isolate  \
# 0  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...   362      0.0
# 1  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...    22      0.0
# 2  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...   190      0.0
# 3  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...   320      1.0
#
#   mutation target annotation  oriC  presence promoter  pseudogene  \
# 0                       yjjX   0.0       1.0       {}         0.0
# 1                       yjjX   0.0       1.0       {}         0.0
# 2                       yjjX   0.0       1.0       {}         0.0
# 3                       yjjX   0.0       1.0       {}         0.0
#
#                 range     sample  tech_rep terminator
# 0  (4633743, 4633743)   9 30 0 1       1.0         {}
# 1  (4633634, 4633634)  10 32 0 1       1.0         {}
# 2  (4633657, 4633657)  11 63 0 1       1.0         {}
# 3  (4633657, 4633657)  12 60 1 1       1.0         {}

# %%
from Bio import SeqIO


recs = [rec for rec in SeqIO.parse("./data/NC_000913_3.gb", "genbank")]

mob_sizes = dict()

for rec in recs:
    feats = [feat for feat in rec.features if feat.type == "mobile_element"]
    for feat in feats:
        for annot in feat.qualifiers["mobile_element_type"]:
            mob_name = annot.replace("insertion sequence:",'')
            if mob_name[-1].isdigit() == False:  # Removing annotations describing separate instances of a MOB.
                mob_name = mob_name[:-1]
            mob_size = len(feat.location)
            if mob_name not in mob_sizes.keys():  # Assuming that all MOBs have the same length.
                mob_sizes[mob_name] = mob_size
mob_sizes
# Out:
# {'IS186': 1345,
#  'IS1': 768,
#  'IS911': 335,
#  'IS30': 1221,
#  'IS5': 1195,
#  'IS': 312,
#  'IS3': 1255,
#  'IS2': 1331,
#  'IS609': 1748,
#  'IS5L': 1195,
#  'IS150': 1443,
#  'IS4': 1426,
#  'IS600': 327}

# %%
import os, sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from mutil.mut import get_mut_size, get_mob_size, is_genetic_mut, is_coding_mut, predict_mutation_effect_on_feature, get_SNP_aa_pos, get_DEL_INS_MOB_aa_start_pos, get_DEL_AA_range


meta_muts["genetic"] = meta_muts["Details"].apply(is_genetic_mut)
meta_muts["coding"] = meta_muts["Details"].apply(is_coding_mut)
meta_muts["mutation size"] = meta_muts.apply(get_mut_size, axis=1)  # get_mut_size currently doesn't return MOB mut sizes. Isn't something currently necessary.

# TODO: integrate MOB size logic into get_mut_size
meta_muts["mutation size"] = meta_muts.apply(lambda r: get_mob_size(r["Sequence Change"], mob_sizes) if r["Mutation Type"] == "MOB" else r["mutation size"], axis=1)

# %%
def _set_geno_feat_effect(mut):
    for gf in mut["genomic features"]:
        gf["predicted mutation effect"] = predict_mutation_effect_on_feature(mut, gf)

meta_muts.apply(lambda m: _set_geno_feat_effect(m), axis=1)
# Out:
# 0    None
# 1    None
# 2    None
# 3    None
# dtype: object

# %%
def _is_gene_trunc(geno_feats, gene_name):
    is_gene_trunc = False
    for gf in geno_feats:
        if (gf["name"] == gene_name) & (gf['predicted mutation effect'] == 'truncation'):
            
            is_gene_trunc = True
            break
    return is_gene_trunc


meta_muts["truncation"] = meta_muts["genomic features"].apply(lambda gfs: _is_gene_trunc(gfs, "yjjX"))

# %%
def _get_SNP_AA_range(mut_details_str):
    SNP_AA_range = ()
    AA_pos = get_SNP_aa_pos(mut_details_str)
    SNP_AA_range = (AA_pos, AA_pos)
    return SNP_AA_range

meta_muts["AA range"] = None
meta_muts["AA range"] = meta_muts.apply(lambda r: _get_SNP_AA_range(r["Details"]) if ((r["Mutation Type"] == "SNP") & (r["coding"]==1)) else r["AA range"], axis=1)
meta_muts[meta_muts["Mutation Type"].isin(["SNP"])].head()
# Out:
#            Details Mutation Type   Position RBS Reference Seq Sequence Change  \
# 0  M1M (ATG→ATA) †           SNP  4633743.0  {}     NC_000913             C→T
# 1   E38K (GAG→AAG)           SNP  4633634.0  {}     NC_000913             C→T
# 2   C30Y (TGC→TAC)           SNP  4633657.0  {}     NC_000913             C→T
# 3   C30Y (TGC→TAC)           SNP  4633657.0  {}     NC_000913             C→T
#
#   TFBS   ale  coding            exp  flask gene RegulonDB ID  genetic  \
# 0   {}   9.0    True  ndh-cydB-appC   30.0    {ECK120002327}     True
# 1   {}  10.0    True  ndh-cydB-appC   32.0    {ECK120002327}     True
# 2   {}  11.0    True  ndh-cydB-appC   63.0    {ECK120002327}     True
# 3   {}  12.0    True  ndh-cydB-appC   60.0    {ECK120002327}     True
#
#                                     genetic features  \
# 0  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...
# 1  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...
# 2  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...
# 3  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...
#
#                                     genomic features index  isolate  \
# 0  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...   362      0.0
# 1  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...    22      0.0
# 2  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...   190      0.0
# 3  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...   320      1.0
#
#   mutation target annotation  oriC  presence promoter  pseudogene  \
# 0                       yjjX   0.0       1.0       {}         0.0
# 1                       yjjX   0.0       1.0       {}         0.0
# 2                       yjjX   0.0       1.0       {}         0.0
# 3                       yjjX   0.0       1.0       {}         0.0
#
#                 range     sample  tech_rep terminator  mutation size  \
# 0  (4633743, 4633743)   9 30 0 1       1.0         {}              1
# 1  (4633634, 4633634)  10 32 0 1       1.0         {}              1
# 2  (4633657, 4633657)  11 63 0 1       1.0         {}              1
# 3  (4633657, 4633657)  12 60 1 1       1.0         {}              1
#
#    truncation  AA range
# 0        True    (1, 1)
# 1       False  (38, 38)
# 2       False  (30, 30)
# 3       False  (30, 30)

# %%
from mutil.gff import get_df_from_csv
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
    
gff_df = get_df_from_csv("./data/gff/yjjX.gff")

def update_gff_feature_description(feature, attribute):
    updated_feature = feature
    if "Note=Substrate binding" in attribute:
        updated_feature = "Substrate binding region"
    if "Note=Manganese or magnesium" in attribute:
        updated_feature = "Manganese or magnesium mental binding site"
    return updated_feature


gff_df = gff_df[~(gff_df["feature"].isin(["Sequence conflict", "Mutagenesis", "Initiator methionine", "Helix", "Turn", "Beta strand"]))]  # Don't care about these
gff_df["feature"] = gff_df.apply(lambda r: update_gff_feature_description(r["feature"], r["attribute"]), axis=1)

# Additional annotations from Pfam (on EcoCyc)
# gff_df = gff_df.append({"feature": "NTPase_I-T Pfam domain", "start": 7, "end": 166}, ignore_index=True)

gff_df.sort_values(by="start")
gff_df
# Out:
#   seqname     source                                     feature  start  end  \
# 0  P39411  UniProtKB                                       Chain      1  170
# 1  P39411  UniProtKB                    Substrate binding region      8   13
# 2  P39411  UniProtKB                    Substrate binding region     68   69
# 3  P39411  UniProtKB  Manganese or magnesium mental binding site     38   38
# 4  P39411  UniProtKB  Manganese or magnesium mental binding site     68   68
#
#   score strand frame                                          attribute   9
# 0     .      .     .  ID=PRO_0000156337;Note=Inosine/xanthosine trip... NaN
# 1     .      .     .  Note=Substrate binding;Ontology_term=ECO:00002... NaN
# 2     .      .     .  Note=Substrate binding;Ontology_term=ECO:00002... NaN
# 3     .      .     .  Note=Manganese or magnesium;Ontology_term=ECO:... NaN
# 4     .      .     .  Note=Manganese or magnesium;Ontology_term=ECO:... NaN

# %%
# TODO: change "all_glpK_interface_df" to something else

# getting interface regions from mutfunc's precalculated outputs
all_glpK_interface_df = pd.read_csv('./data/mutfunc_full/yjjX_interfaces.tab', sep='\t', header=None)
all_glpK_interface_df.columns = ["pdb","prot_a","prot_b","evidence","chain","aa_wt","aa_mt","pdb_pos","uniprot_pos","mut","dG_wt","dG_mt","ddG","dG_wt_sd","dG_mt_sd", "ddG_sd"]
all_glpK_interface_df["NC_000913v3_pos"] = all_glpK_interface_df["uniprot_pos"] + 1  # Adding 1 to account for initiator methionine (start codon) within NC_000913v3 AA ref
all_glpK_interface_df
# Out:
#                                           pdb  prot_a  prot_b evidence chain  \
# 0     P39411-P39411-EXP-1u5w-pdb3-F-0-E-0.pdb  P39411  P39411      EXP     A
# 1     P39411-P39411-EXP-1u5w-pdb3-F-0-E-0.pdb  P39411  P39411      EXP     A
# 2     P39411-P39411-EXP-1u5w-pdb3-F-0-E-0.pdb  P39411  P39411      EXP     A
# 3     P39411-P39411-EXP-1u5w-pdb3-F-0-E-0.pdb  P39411  P39411      EXP     A
# 4     P39411-P39411-EXP-1u5w-pdb3-F-0-E-0.pdb  P39411  P39411      EXP     A
# ...                                       ...     ...     ...      ...   ...
# 1655  P39411-P39411-EXP-1u5w-pdb3-F-0-E-0.pdb  P39411  P39411      EXP     B
# 1656  P39411-P39411-EXP-1u5w-pdb3-F-0-E-0.pdb  P39411  P39411      EXP     B
# 1657  P39411-P39411-EXP-1u5w-pdb3-F-0-E-0.pdb  P39411  P39411      EXP     B
# 1658  P39411-P39411-EXP-1u5w-pdb3-F-0-E-0.pdb  P39411  P39411      EXP     B
# 1659  P39411-P39411-EXP-1u5w-pdb3-F-0-E-0.pdb  P39411  P39411      EXP     B
#
#      aa_wt aa_mt  pdb_pos  uniprot_pos     mut     dG_wt     dG_mt       ddG  \
# 0        W     A       90           90   WA90A  4.186050  6.821188  2.635138
# 1        W     C       90           90   WA90C  4.586894  7.469766  2.882872
# 2        W     D       90           90   WA90D  4.191682  8.043704  3.852022
# 3        W     E       90           90   WA90E  4.316510  7.292560  2.976050
# 4        W     F       90           90   WA90F  4.399760  4.369536 -0.030224
# ...    ...   ...      ...          ...     ...       ...       ...       ...
# 1655     H     S      169          169  HB169S  5.195986  5.483526  0.287540
# 1656     H     T      169          169  HB169T  5.210294  5.444138  0.233844
# 1657     H     V      169          169  HB169V  5.221500  4.231318 -0.990182
# 1658     H     W      169          169  HB169W  5.178334  4.848346 -0.329988
# 1659     H     Y      169          169  HB169Y  5.224274  4.733868 -0.490406
#
#       dG_wt_sd  dG_mt_sd    ddG_sd  NC_000913v3_pos
# 0     0.400612  0.897989  0.632237               91
# 1     0.034782  0.716512  0.682362               91
# 2     0.286227  0.995652  0.806663               91
# 3     0.228080  0.448962  0.251118               91
# 4     0.405339  1.240901  1.500742               91
# ...        ...       ...       ...              ...
# 1655  0.061543  0.053406  0.067100              170
# 1656  0.053618  0.042732  0.067445              170
# 1657  0.028443  0.000090  0.028500              170
# 1658  0.099939  0.120134  0.146561              170
# 1659  0.022279  0.374764  0.363093              170
#
# [1660 rows x 17 columns]

# %%
df = all_glpK_interface_df.copy()
df = df.drop(columns=["aa_wt", "aa_mt", "mut", "dG_wt", "dG_mt", "ddG", "dG_wt_sd", "dG_mt_sd", "ddG_sd"]).drop_duplicates()
display(df.prot_a.unique(), df.prot_b.unique())
# Out:
# array(['P39411'], dtype=object)
# array(['P39411'], dtype=object)

# %%
from mutil.gff import group_sequences

# %%
# TODO: change across the NB "GlpK_GlpK" to something else

GlpK_GlpK_interface_df = all_glpK_interface_df[((all_glpK_interface_df["prot_a"]=="P39411") & (all_glpK_interface_df["prot_b"]=="P39411"))]
GlpK_GlpK_interface_AAs = GlpK_GlpK_interface_df["NC_000913v3_pos"].unique()

# Outputting ranges for manual input into R
GlpK_GlpK_interface_AAs.sort()
GlpK_GlpK_interface_AA_ranges = group_sequences(GlpK_GlpK_interface_AAs)
GlpK_GlpK_interface_AA_ranges
# Out:
# [[27, 28],
#  [56],
#  [84],
#  [86, 87],
#  [91],
#  [101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114],
#  [131],
#  [144],
#  [146, 147, 148, 149],
#  [151, 152],
#  [156, 157],
#  [159, 160, 161],
#  [163, 164, 165],
#  [167, 168],
#  [170, 171],
#  [173, 174],
#  [176]]

# %%
for rng_l in GlpK_GlpK_interface_AA_ranges:
    gff_df = gff_df.append({"feature": "YjjX subunit interface", "start": rng_l[0], "end": rng_l[-1], "color": "#4169E1"}, ignore_index=True)

# %%
def _get_mut_subgenic_feats(mut_AA_pos_range, gff_df):
    mut_subgenic_feats = set()
    print(mut_AA_pos_range)
    mut_AA_pos_set = set(range(mut_AA_pos_range[0], mut_AA_pos_range[1] + 1))  # +1 so that "range" function will count last position
    for _, r in gff_df.iterrows():
        if r["feature"] != "Chain":
            feat_AA_pos_set = set(range(r["start"], r["end"] + 1))  # +1 so that "range" function will count last position
            if len(mut_AA_pos_set & feat_AA_pos_set) > 0:
                mut_subgenic_feats.add(r["feature"])
    if len(mut_subgenic_feats) == 0:
        mut_subgenic_feats.add("unannotated region")
    return mut_subgenic_feats


meta_muts["subgenic features"] = meta_muts.apply(lambda r: _get_mut_subgenic_feats(r["AA range"], gff_df), axis=1)
meta_muts.head()
# Out:
# (1, 1)
# (38, 38)
# (30, 30)
# (30, 30)
#            Details Mutation Type   Position RBS Reference Seq Sequence Change  \
# 0  M1M (ATG→ATA) †           SNP  4633743.0  {}     NC_000913             C→T
# 1   E38K (GAG→AAG)           SNP  4633634.0  {}     NC_000913             C→T
# 2   C30Y (TGC→TAC)           SNP  4633657.0  {}     NC_000913             C→T
# 3   C30Y (TGC→TAC)           SNP  4633657.0  {}     NC_000913             C→T
#
#   TFBS   ale  coding            exp  flask gene RegulonDB ID  genetic  \
# 0   {}   9.0    True  ndh-cydB-appC   30.0    {ECK120002327}     True
# 1   {}  10.0    True  ndh-cydB-appC   32.0    {ECK120002327}     True
# 2   {}  11.0    True  ndh-cydB-appC   63.0    {ECK120002327}     True
# 3   {}  12.0    True  ndh-cydB-appC   60.0    {ECK120002327}     True
#
#                                     genetic features  \
# 0  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...
# 1  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...
# 2  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...
# 3  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...
#
#                                     genomic features index  isolate  \
# 0  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...   362      0.0
# 1  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...    22      0.0
# 2  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...   190      0.0
# 3  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...   320      1.0
#
#   mutation target annotation  oriC  presence promoter  pseudogene  \
# 0                       yjjX   0.0       1.0       {}         0.0
# 1                       yjjX   0.0       1.0       {}         0.0
# 2                       yjjX   0.0       1.0       {}         0.0
# 3                       yjjX   0.0       1.0       {}         0.0
#
#                 range     sample  tech_rep terminator  mutation size  \
# 0  (4633743, 4633743)   9 30 0 1       1.0         {}              1
# 1  (4633634, 4633634)  10 32 0 1       1.0         {}              1
# 2  (4633657, 4633657)  11 63 0 1       1.0         {}              1
# 3  (4633657, 4633657)  12 60 1 1       1.0         {}              1
#
#    truncation  AA range                             subgenic features
# 0        True    (1, 1)                          {unannotated region}
# 1       False  (38, 38)  {Manganese or magnesium mental binding site}
# 2       False  (30, 30)                          {unannotated region}
# 3       False  (30, 30)                          {unannotated region}

# %%
# TODO: put this in mutil since I end up using it in every gene-based mut-needle-plot
# For mutfunc with methionine being considered as AA 1
mut_set = set()  # to only get unique
for _, r in meta_muts.iterrows():
    if (r["Mutation Type"] == "SNP") and ('*' not in r["Details"]):
        s = r["Details"]
        out_str = "P39411 " + s[:s.find(" (")]
        mut_set.add(out_str)

for s in mut_set:
    print(s)
# Out:
# P39411 M1M
# P39411 C30Y
# P39411 E38K

# %%
meta_muts["AA change"] = meta_muts.apply(lambda r: r["Details"][:r["Details"].find("(")].strip() if r["Mutation Type"]=="SNP" else "", axis=1)
meta_muts[meta_muts["Mutation Type"]=="SNP"].head()
# Out:
#            Details Mutation Type   Position RBS Reference Seq Sequence Change  \
# 0  M1M (ATG→ATA) †           SNP  4633743.0  {}     NC_000913             C→T
# 1   E38K (GAG→AAG)           SNP  4633634.0  {}     NC_000913             C→T
# 2   C30Y (TGC→TAC)           SNP  4633657.0  {}     NC_000913             C→T
# 3   C30Y (TGC→TAC)           SNP  4633657.0  {}     NC_000913             C→T
#
#   TFBS   ale  coding            exp  flask gene RegulonDB ID  genetic  \
# 0   {}   9.0    True  ndh-cydB-appC   30.0    {ECK120002327}     True
# 1   {}  10.0    True  ndh-cydB-appC   32.0    {ECK120002327}     True
# 2   {}  11.0    True  ndh-cydB-appC   63.0    {ECK120002327}     True
# 3   {}  12.0    True  ndh-cydB-appC   60.0    {ECK120002327}     True
#
#                                     genetic features  \
# 0  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...
# 1  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...
# 2  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...
# 3  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...
#
#                                     genomic features index  isolate  \
# 0  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...   362      0.0
# 1  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...    22      0.0
# 2  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...   190      0.0
# 3  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...   320      1.0
#
#   mutation target annotation  oriC  presence promoter  pseudogene  \
# 0                       yjjX   0.0       1.0       {}         0.0
# 1                       yjjX   0.0       1.0       {}         0.0
# 2                       yjjX   0.0       1.0       {}         0.0
# 3                       yjjX   0.0       1.0       {}         0.0
#
#                 range     sample  tech_rep terminator  mutation size  \
# 0  (4633743, 4633743)   9 30 0 1       1.0         {}              1
# 1  (4633634, 4633634)  10 32 0 1       1.0         {}              1
# 2  (4633657, 4633657)  11 63 0 1       1.0         {}              1
# 3  (4633657, 4633657)  12 60 1 1       1.0         {}              1
#
#    truncation  AA range                             subgenic features  \
# 0        True    (1, 1)                          {unannotated region}
# 1       False  (38, 38)  {Manganese or magnesium mental binding site}
# 2       False  (30, 30)                          {unannotated region}
# 3       False  (30, 30)                          {unannotated region}
#
#   AA change
# 0       M1M
# 1      E38K
# 2      C30Y
# 3      C30Y

# %%
# mut_conservation_df = pd.read_csv("./data/mutfunc/yjjX/conservation.tab", sep='\t', comment='#')
# mut_conservation_df["AA change"] = mut_conservation_df.apply(lambda r: r["refaa"] + str(r["posaa"]) + r["altaa"], axis=1)
# meta_muts["conservation (SIFT)"] = meta_muts.apply(lambda r: True if r["AA change"] in mut_conservation_df["AA change"].values else False, axis=1)
# meta_muts[meta_muts["conservation (SIFT)"]].head()
meta_muts["conservation (SIFT)"] = False

# %%
mut_stability_df = pd.read_csv("./data/mutfunc/yjjX/stability.tab", sep='\t', comment='#')
mut_stability_df["AA change"] = mut_stability_df.apply(lambda r: r["refaa"] + str(r["posaa"]) + r["altaa"], axis=1)
meta_muts["stability (ΔΔGpred)"] = meta_muts.apply(lambda r: True if r["AA change"] in mut_stability_df["AA change"].values else False, axis=1)
meta_muts[meta_muts["stability (ΔΔGpred)"]].head()
# Out:
#           Details Mutation Type   Position RBS Reference Seq Sequence Change  \
# 2  C30Y (TGC→TAC)           SNP  4633657.0  {}     NC_000913             C→T
# 3  C30Y (TGC→TAC)           SNP  4633657.0  {}     NC_000913             C→T
#
#   TFBS   ale  coding            exp  flask gene RegulonDB ID  genetic  \
# 2   {}  11.0    True  ndh-cydB-appC   63.0    {ECK120002327}     True
# 3   {}  12.0    True  ndh-cydB-appC   60.0    {ECK120002327}     True
#
#                                     genetic features  \
# 2  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...
# 3  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...
#
#                                     genomic features index  isolate  \
# 2  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...   190      0.0
# 3  [{'name': 'yjjX', 'RegulonDB ID': 'ECK12000232...   320      1.0
#
#   mutation target annotation  oriC  presence promoter  pseudogene  \
# 2                       yjjX   0.0       1.0       {}         0.0
# 3                       yjjX   0.0       1.0       {}         0.0
#
#                 range     sample  tech_rep terminator  mutation size  \
# 2  (4633657, 4633657)  11 63 0 1       1.0         {}              1
# 3  (4633657, 4633657)  12 60 1 1       1.0         {}              1
#
#    truncation  AA range     subgenic features AA change  conservation (SIFT)  \
# 2       False  (30, 30)  {unannotated region}      C30Y                False
# 3       False  (30, 30)  {unannotated region}      C30Y                False
#
#    stability (ΔΔGpred)
# 2                 True
# 3                 True

# %%
# TODO: need to combine a few of the features

feat_set = set(gff_df["feature"])
feat_set |= {"unannotated region"}
feat_mut_cnt_df = pd.DataFrame(0,
                               columns=["coding disruption", "functional disruption", "structural disruption", "unknown effect"],
                               index=feat_set)
feat_mut_cnt_df

for _, r in meta_muts.iterrows():
    for f in r["subgenic features"]:
        effect_predicted = False
        if r["truncation"]:
            feat_mut_cnt_df.at[f, "coding disruption"] += 1
            effect_predicted = True
        else:
            if r["conservation (SIFT)"]:
                feat_mut_cnt_df.at[f, "functional disruption"] += 1
                effect_predicted = True
            if r["stability (ΔΔGpred)"]:
                feat_mut_cnt_df.at[f, "structural disruption"] += 1
                effect_predicted = True
        if not effect_predicted:
            feat_mut_cnt_df.at[f, "unknown effect"] += 1
# feat_mut_cnt_df = feat_mut_cnt_df[~(feat_mut_cnt_df.index.isin(["Turn", "Helix", "Beta strand"]))]
feat_mut_cnt_df = feat_mut_cnt_df[(feat_mut_cnt_df.T != 0).any(axis=0)]  # remove rows that are all zeros
feat_mut_cnt_df = feat_mut_cnt_df.loc[:, (feat_mut_cnt_df != 0).any(axis=0)]  # remove columns that are all zeros
feat_mut_cnt_df
# Out:
#                                             coding disruption  \
# Manganese or magnesium mental binding site                  0
# unannotated region                                          1
#
#                                             structural disruption  \
# Manganese or magnesium mental binding site                      0
# unannotated region                                              2
#
#                                             unknown effect
# Manganese or magnesium mental binding site               1
# unannotated region                                       0

# %%
meta_muts.exp.unique()
# Out:
# array(['ndh-cydB-appC'], dtype=object)

# %%
exp_id_d = {
    "ndh-cydB-appC": "ndh-cydB-appC",
}

study_color_d = {
    "ndh-cydB-appC": "#4878D0",
}


# This is done specifically to expand the count of rows that describe the full range of AA per mutations.
AA_rng_exp_df = pd.DataFrame(columns=["AA position", "mutation type", "disrupt coding seq", "disrupt func",
                                      "disrupt struct"
                                      ])
for _, m in meta_muts.iterrows():
    AA_positions = set(range(m["AA range"][0], m["AA range"][1] + 1))

    disrupt_coding = 0
    if m["truncation"]:
        disrupt_coding = 1
        AA_positions = {m["AA range"][0]}

    disrupt_func = 0
    if m["conservation (SIFT)"]:
        disrupt_func = 1

    disrupt_struct = 0
    if "stability (ΔΔGpred)" in m.index and m["stability (ΔΔGpred)"]:
        disrupt_struct = 1

    for p in AA_positions:
        doi = exp_id_d[m["exp"]]
        AA_rng_exp_df = AA_rng_exp_df.append(
            {"AA position": p,
             "mutation type": m["Mutation Type"],
             "disrupt coding seq": disrupt_coding,
             "disrupt func": disrupt_func,
             "disrupt struct": disrupt_struct,
             "study": doi,
             "study color": study_color_d[doi]
            },
            ignore_index=True)
AA_rng_exp_df["mutation type"] = AA_rng_exp_df["mutation type"].apply(lambda mt: "CNV" if mt == "AMP" else mt)
AA_rng_exp_df
# Out:
#   AA position mutation type disrupt coding seq disrupt func disrupt struct  \
# 0           1           SNP                  1            0              0
# 1          38           SNP                  0            0              0
# 2          30           SNP                  0            0              1
# 3          30           SNP                  0            0              1
#
#            study study color
# 0  ndh-cydB-appC     #4878D0
# 1  ndh-cydB-appC     #4878D0
# 2  ndh-cydB-appC     #4878D0
# 3  ndh-cydB-appC     #4878D0

# %%
# Just want to count the mutation rows
aa_mut_cnt_df = pd.DataFrame()
for t, gdf in AA_rng_exp_df.groupby(list(AA_rng_exp_df.columns)):
    c = len(gdf)
    df = gdf.copy()
    df = df.drop_duplicates()
    df["mutation count"] = c
    aa_mut_cnt_df = aa_mut_cnt_df.append(df, ignore_index=True)
aa_mut_cnt_df["name"] = aa_mut_cnt_df.apply(lambda r: r["mutation type"] + " AA " + str(r["AA position"]), axis=1)
aa_mut_cnt_df
# Out:
#   AA position mutation type disrupt coding seq disrupt func disrupt struct  \
# 0           1           SNP                  1            0              0
# 1          30           SNP                  0            0              1
# 2          38           SNP                  0            0              0
#
#            study study color  mutation count       name
# 0  ndh-cydB-appC     #4878D0               1   SNP AA 1
# 1  ndh-cydB-appC     #4878D0               2  SNP AA 30
# 2  ndh-cydB-appC     #4878D0               1  SNP AA 38

# %%
def get_mut_color(r):
    mut_color = "grey"
    if r["disrupt coding seq"] == 1:  # red has priority over all other colors
        mut_color = 'red'
    else:
        if (r["disrupt func"] == 1) & (r["disrupt struct"] == 1):
            mut_color = "#A52A2A"
        elif (r["disrupt func"] == 1) & (r["disrupt struct"] == 0):
            mut_color = "#FFA500"
        elif (r["disrupt func"] == 0) & (r["disrupt struct"] == 1):
            mut_color = "#A020F0"
        else:
            mut_color = '#ABABAB'  # unknown
    return mut_color


aa_mut_cnt_df["color"] = aa_mut_cnt_df.apply(lambda r: get_mut_color(r), axis=1)
aa_mut_cnt_df
# Out:
#   AA position mutation type disrupt coding seq disrupt func disrupt struct  \
# 0           1           SNP                  1            0              0
# 1          30           SNP                  0            0              1
# 2          38           SNP                  0            0              0
#
#            study study color  mutation count       name    color
# 0  ndh-cydB-appC     #4878D0               1   SNP AA 1      red
# 1  ndh-cydB-appC     #4878D0               2  SNP AA 30  #A020F0
# 2  ndh-cydB-appC     #4878D0               1  SNP AA 38  #ABABAB

# %%
aa_mut_cnt_df.to_csv("./yjjX_aa_muts.csv", index=False)  # For R and other IPYNBs

# %%
feat_to_color_d = {
    "Chain": "white",  # don't need to find intermediate grey chains if the overlap is clean.
    "Helix": "#937860",
    "Turn": "#f58231",
    "Beta strand": "#8C8C8C",
    'Substrate binding region':'#911EB4',
    'Manganese or magnesium mental binding site':'#4169E1',
    'YjjX subunit interface':'#469990',
    'NTPase_I-T Pfam domain':'#FCAD74',
}


gff_df["color"] = gff_df.apply(lambda r: feat_to_color_d[r["feature"]], axis=1)
gff_df.to_csv("./yjjX_aa_feats.csv", index=False)  # For R
gff_df.head()
# Out:
#   seqname     source                                     feature  start  end  \
# 0  P39411  UniProtKB                                       Chain      1  170
# 1  P39411  UniProtKB                    Substrate binding region      8   13
# 2  P39411  UniProtKB                    Substrate binding region     68   69
# 3  P39411  UniProtKB  Manganese or magnesium mental binding site     38   38
# 4  P39411  UniProtKB  Manganese or magnesium mental binding site     68   68
#
#   score strand frame                                          attribute   9  \
# 0     .      .     .  ID=PRO_0000156337;Note=Inosine/xanthosine trip... NaN
# 1     .      .     .  Note=Substrate binding;Ontology_term=ECO:00002... NaN
# 2     .      .     .  Note=Substrate binding;Ontology_term=ECO:00002... NaN
# 3     .      .     .  Note=Manganese or magnesium;Ontology_term=ECO:... NaN
# 4     .      .     .  Note=Manganese or magnesium;Ontology_term=ECO:... NaN
#
#      color
# 0    white
# 1  #911EB4
# 2  #911EB4
# 3  #4169E1
# 4  #4169E1

# %%
# output feature data for NGL
ngl_feat_df = gff_df[~(gff_df.feature.isin(["Turn", "Helix", "Beta strand"]))].copy()
ngl_feat_df["size"] = ngl_feat_df.apply(lambda r: r["end"] - r["start"] + 1, axis=1)
ngl_feat_df = ngl_feat_df[["feature", "start", "end", "color", "size"]]
ngl_feat_df = ngl_feat_df.sort_values("size", ascending=False)
ngl_feat_df = ngl_feat_df.reset_index(drop=True)  # json explicitly uses the indexes

# Need to so that the positions defined by AAs now match structural residues
ngl_feat_df["start"] = ngl_feat_df["start"] - 1
ngl_feat_df["end"] = ngl_feat_df["end"] - 1
display(ngl_feat_df)
with open('YjjX_feats.json', 'w') as outfile:   # for NGL
    outfile.write(ngl_feat_df.to_json())
# Out:
#                                        feature  start  end    color  size
# 0                                        Chain      0  169    white   170
# 1                       YjjX subunit interface    100  113  #469990    14
# 2                     Substrate binding region      7   12  #911EB4     6
# 3                       YjjX subunit interface    145  148  #469990     4
# 4                       YjjX subunit interface    162  164  #469990     3
# 5                       YjjX subunit interface    158  160  #469990     3
# 6                       YjjX subunit interface    150  151  #469990     2
# 7                     Substrate binding region     67   68  #911EB4     2
# 8                       YjjX subunit interface    172  173  #469990     2
# 9                       YjjX subunit interface    169  170  #469990     2
# 10                      YjjX subunit interface     26   27  #469990     2
# 11                      YjjX subunit interface    166  167  #469990     2
# 12                      YjjX subunit interface     85   86  #469990     2
# 13                      YjjX subunit interface    155  156  #469990     2
# 14                      YjjX subunit interface    130  130  #469990     1
# 15                      YjjX subunit interface    143  143  #469990     1
# 16                      YjjX subunit interface     90   90  #469990     1
# 17                      YjjX subunit interface     83   83  #469990     1
# 18                      YjjX subunit interface     55   55  #469990     1
# 19  Manganese or magnesium mental binding site     67   67  #4169E1     1
# 20  Manganese or magnesium mental binding site     37   37  #4169E1     1
# 21                      YjjX subunit interface    175  175  #469990     1

# %%
out_mut_df = aa_mut_cnt_df[["AA position", "mutation count", "mutation type", "name", "color"]].copy()
out_mut_df["residue pos"] = out_mut_df["AA position"] - 1
display(out_mut_df)
with open('YjjX_aa_muts.json', 'w') as outfile:  # for NGL
    outfile.write(out_mut_df.to_json())
# Out:
#   AA position  mutation count mutation type       name    color residue pos
# 0           1               1           SNP   SNP AA 1      red           0
# 1          30               2           SNP  SNP AA 30  #A020F0          29
# 2          38               1           SNP  SNP AA 38  #ABABAB          37
